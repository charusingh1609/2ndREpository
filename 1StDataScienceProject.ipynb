# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv(r"C:\\Users\\Hp\Desktop\data2.csv")
data.head()
# Out:
#    s no.       date       state  hospitalized_with_symptoms  Unnamed: 4  \
# 0      1  11/4/2021  mahahtrara                          45         NaN
# 1      2  11/4/2021  mahahtrara                          76         NaN
# 2      3  11/4/2021      punjab                          23         NaN
# 3      4  12/4/2021      punjab                          34         NaN
# 4      5  12/4/2021      punjab                          45         NaN
#
#    Unnamed: 5 intensive_care  Unnamed: 7  total_hospitalized  Unnamed: 9  ...  \
# 0         NaN            yes         NaN                  45         NaN  ...
# 1         NaN             no         NaN                  76         NaN  ...
# 2         NaN             no         NaN                  23         NaN  ...
# 3         NaN             no         NaN                  34         NaN  ...
# 4         NaN             no         NaN                  45         NaN  ...
#
# ...

# %%
data.columns
# Out:
# Index(['s no.', 'date', 'state', 'hospitalized_with_symptoms', 'Unnamed: 4',
#        'Unnamed: 5', 'intensive_care', 'Unnamed: 7', 'total_hospitalized',
#        'Unnamed: 9', 'home_quarntine', 'Unnamed: 11', 'total_confirmed_cases',
#        'Unnamed: 13', 'Unnamed: 14', 'new_confirmed_cases', 'Unnamed: 16',
#        'Unnamed: 17', 'death', 'recovered', 'total_cases'],
#       dtype='object')

# %%
data.describe()
# Out:
#            s no.  hospitalized_with_symptoms  Unnamed: 4  Unnamed: 5  \
# count  70.000000                   70.000000         0.0         0.0
# mean   35.500000                   64.628571         NaN         NaN
# std    20.351085                   48.241894         NaN         NaN
# min     1.000000                   12.000000         NaN         NaN
# 25%    18.250000                   35.000000         NaN         NaN
# 50%    35.500000                   62.500000         NaN         NaN
# 75%    52.750000                   89.000000         NaN         NaN
# max    70.000000                  400.000000         NaN         NaN
#
#        Unnamed: 7  total_hospitalized  Unnamed: 9  home_quarntine  \
# count         0.0           70.000000         0.0       70.000000
# mean          NaN           64.628571         NaN       48.242857
# std           NaN           48.241894         NaN       23.397904
# min           NaN           12.000000         NaN        7.000000
# ...

# %%
data.isnull().sum()
# Out:
# s no.                          0
# date                           0
# state                          0
# hospitalized_with_symptoms     0
# Unnamed: 4                    70
# Unnamed: 5                    70
# intensive_care                 0
# Unnamed: 7                    70
# total_hospitalized             0
# Unnamed: 9                    70
# home_quarntine                 0
# Unnamed: 11                   70
# total_confirmed_cases          0
# Unnamed: 13                   70
# Unnamed: 14                   70
# new_confirmed_cases            0
# Unnamed: 16                   70
# Unnamed: 17                   70
# death                          0
# recovered                      0
# total_cases                   70
# dtype: int64

# %% [markdown]
# # the variables with scatterplots

# %%
sns.relplot(x="state",y="home_quarntine",data=data)

# %%
sns.pairplot(data)

# %%
sns.relplot(x="total_confirmed_cases",y="new_confirmed_cases",hue='death',data=data)

# %%
sns.relplot(x='death',y='recovered',data=data)

# %%
data.columns
# Out:
# Index(['s no.', 'date', 'state', 'hospitalized_with_symptoms', 'Unnamed: 4',
#        'Unnamed: 5', 'intensive_care', 'Unnamed: 7', 'total_hospitalized',
#        'Unnamed: 9', 'home_quarntine', 'Unnamed: 11', 'total_confirmed_cases',
#        'Unnamed: 13', 'Unnamed: 14', 'new_confirmed_cases', 'Unnamed: 16',
#        'Unnamed: 17', 'death', 'recovered', 'total_cases'],
#       dtype='object')

# %%
sns.catplot(x="death",y="home_quarntine",data=data)

# %%
sns.catplot(x="hospitalized_with_symptoms",y="recovered",hue='death', data=data)
print("stay home,stay safe")
# Out:
# stay home,stay safe

# %%
data.columns
# Out:
# Index(['s no.', 'date', 'state', 'hospitalized_with_symptoms', 'Unnamed: 4',
#        'Unnamed: 5', 'intensive_care', 'Unnamed: 7', 'total_hospitalized',
#        'Unnamed: 9', 'home_quarntine', 'Unnamed: 11', 'total_confirmed_cases',
#        'Unnamed: 13', 'Unnamed: 14', 'new_confirmed_cases', 'Unnamed: 16',
#        'Unnamed: 17', 'death', 'recovered', 'total_cases'],
#       dtype='object')

# %%
sns.relplot(x='state',y='recovered',kind='line',data=data)

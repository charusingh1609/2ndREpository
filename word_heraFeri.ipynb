# %%
from itertools import permutations 

import string 

  

s = "jhon"

a = string.ascii_letters 

p = permutations(s) 

  
#  dictionary 

d = [] 

for i in list(p): 

  

    # Print only if not in dictionary 

    if (i not in d): 

        d.append(i) 

        print(''.join(i))
from itertools import permutations 

import string 

  

s = "jhon"

a = string.ascii_letters 

p = permutations(s) 

  
#  dictionary 

d = [] 

for i in list(p): 

  

    # Print only if not in dictionary 

    if (i not in d): 

        d.append(i) 

        print(''.join(i))
# Out:
# jhon
# jhno
# john
# jonh
# jnho
# jnoh
# hjon
# hjno
# hojn
# honj
# hnjo
# hnoj
# ojhn
# ojnh
# ohjn
# ohnj
# onjh
# onhj
# njho
# njoh
# nhjo
# nhoj
# nojh
# nohj
# jhon
# jhno
# john
# jonh
# jnho
# jnoh
# hjon
# hjno
# hojn
# honj
# hnjo
# hnoj
# ojhn
# ojnh
# ohjn
# ohnj
# onjh
# onhj
# njho
# njoh
# nhjo
# nhoj
# nojh
# nohj

# %%
print("*****QUESTION NO. 1 SOLUTION*****")
print("submitted by Charu Singh")

from itertools import permutations 

import string 

  

s = "jhon"

a = string.ascii_letters 

p = permutations(s) 

  
#  dictionary 

d = [] 

for i in list(p): 

  

    # Print only if not in dictionary 

    if (i not in d): 

        d.append(i) 

        print(''.join(i))
# Out:
# *****QUESTION NO. 1 SOLUTION*****
# submitted by Abhinav Kumar Singh
# jhon
# jhno
# john
# jonh
# jnho
# jnoh
# hjon
# hjno
# hojn
# honj
# hnjo
# hnoj
# ojhn
# ojnh
# ohjn
# ohnj
# onjh
# onhj
# njho
# njoh
# nhjo
# nhoj
# nojh
# nohj

# %%
dict = {"Audii": 10000000, "Nishan": 500000, "Ford": 7000000, "BMW": 8000000}
print(sorted(dict.items(), key=lambda kv: (kv[1], kv[0])))
print("Enter name of the car :\n")
t = input()
c = 0
for i in sorted(dict):
    if i == t:
        c = 1
        data = dict[i]
        break

if c == 0:
    print("Car name that u entered does not exsit !!")
    print("Please enter the price of that car :")
    p = input()
    dict[t] = p
else:
    print("Car found !! and the price of that car is :", data)

for k in sorted(dict.keys()):
    print(k, dict[k], end=" ")

    """n = int(input("enter a n value:"))
d = {}

for i in range(n):
    keys = input() # here i have taken keys as strings
    values = int(input()) # here i have taken values as integers
    d[keys] = values
print(d)
"""
# Out:
# [('Nishan', 500000), ('Ford', 7000000), ('BMW', 8000000), ('Audii', 10000000)]
# Enter name of the car :
#
# ford
# Car name that u entered does not exsit !!
# Please enter the price of that car :
# Ford
# Audii 10000000 BMW 8000000 Ford 7000000 Nishan 500000 ford Ford

# %%
dict = {"Audii": 10000000, "Nishan": 500000, "Ford": 7000000, "BMW": 8000000}
print(sorted(dict.items(), key=lambda kv: (kv[1], kv[0])))
print("Enter name of the car :\n")
t = input()
c = 0
for i in sorted(dict):
    if i == t:
        c = 1
        data = dict[i]
        break

if c == 0:
    print("Car name that u entered does not exsit !!")
    print("Please enter the price of that car :")
    p = input()
    dict[t] = p
else:
    print("Car found !! and the price of that car is :", data)

for k in sorted(dict.keys()):
    print(k, dict[k], end=" ")

    """n = int(input("enter a n value:"))
d = {}

for i in range(n):
    keys = input() # here i have taken keys as strings
    values = int(input()) # here i have taken values as integers
    d[keys] = values
print(d)
"""
# Out:
# [('Nishan', 500000), ('Ford', 7000000), ('BMW', 8000000), ('Audii', 10000000)]
# Enter name of the car :

# %%
print("******QUESTION NO.2 SOLUTION******")
print("submitted bY: Charu Singh")
car={"car1":1000000,"car2": 500000," car3 ":"7000000"}
from operator import itemgetter
for  k, v in  sorted(car.items(),key=itemgetter(1)):
   print (k, v)
key=input("enter carname:")
if key in car.keys():
    print("your car is present and value is:")
    print(car[key])
key1=input("enter price ")
if key1 in car.values():
    print("price you entered is found is dictionry and its is:")
    print(car[key1])
else:
    print("sorry your car is not is our list!")
